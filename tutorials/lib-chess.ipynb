# %%
from chess import Board

board = Board()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
from chess import Move

Nf3 = Move.from_uci("g1f3")
board.push(Nf3)  # Make the move
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/5N2/PPPPPPPP/RNBQKB1R b KQkq - 1 1')

# %%
board.pop()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
print(board)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R

# %%
print(board.is_stalemate())
print(board.is_insufficient_material())
print(board.outcome())
# Out:
# False
# False
# None

# %%
print(board.can_claim_threefold_repetition())
print(board.halfmove_clock)
print(board.can_claim_fifty_moves())
print(board.can_claim_draw())
# Out:
# False
# 0
# False
# False

# %%
print(board.is_fivefold_repetition())
print(board.is_seventyfive_moves())
# Out:
# False
# False

# %%
import chess

print(board.is_check())
print(board.is_attacked_by(chess.WHITE, chess.E8))

attackers = board.attackers(chess.WHITE, chess.F3)
print(attackers)

attackers
# Out:
# False
# False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . 1 . 1 .
# . . . . . . 1 .
# SquareSet(0x0000_0000_0000_5040)

# %%
board = chess.Board()
print(board.san(chess.Move(chess.E2, chess.E4)))
print(board.parse_san('Nf3'))
print(board.variation_san([chess.Move.from_uci(m) for m in ["e2e4", "e7e5", "g1f3"]]))
# Out:
# e4
# g1f3
# 1. e4 e5 2. Nf3

# %%
print(board.fen())
print(board.shredder_fen())
board = chess.Board("8/8/8/2k5/4K3/8/8/8 w - - 4 45")
print(board.piece_at(chess.C5))

board.piece_at(chess.C5)
# Out:
# 8/8/8/2k5/4K3/8/8/8 w - - 4 45
# 8/8/8/2k5/4K3/8/8/8 w - - 4 45
# k
# Piece.from_symbol('k')

# %%
board = chess.Board()
board.epd(bm=board.parse_uci("d2d4"))
ops = board.set_epd("1k1r4/pp1b1R2/3q2pp/4p3/2B5/4Q3/PPP2B2/2K5 b - - bm Qd1+; id \"BK.01\";")
ops == {'bm': [chess.Move.from_uci('d6d1')], 'id': 'BK.01'}
# Out:
# True

# %%
import chess.polyglot

book = chess.polyglot.open_reader("data/polyglot/performance.bin")

board = chess.Board()
main_entry = book.find(board)
print(main_entry.move)
print(main_entry.weight)

book.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 3
#       1 import chess.polyglot
# ----> 3 book = chess.polyglot.open_reader("data/polyglot/performance.bin")
#       5 board = chess.Board()
#       6 main_entry = book.find(board)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/polyglot.py:522, in open_reader(path)
#     503 def open_reader(path: StrOrBytesPath) -> MemoryMappedReader:
#     504     """
#     505     Creates a reader for the file at the given path.
#     506
#    (...)    520     c2c4 1 0
#     521     """
# --> 522     return MemoryMappedReader(path)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/polyglot.py:327, in MemoryMappedReader.__init__(self, filename)
#     326 def __init__(self, filename: StrOrBytesPath) -> None:
# --> 327     fd = os.open(filename, os.O_RDONLY | os.O_BINARY if hasattr(os, "O_BINARY") else os.O_RDONLY)
#     328     try:
#     329         self.mmap: Union[mmap.mmap, _EmptyMmap] = mmap.mmap(fd, 0, access=mmap.ACCESS_READ)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/polyglot/performance.bin'

# %%
import chess.pgn

with open("data/pgn/molinari-bordais-1979.pgn") as pgn:
    first_game = chess.pgn.read_game(pgn)

print(first_game.headers["White"])
print(first_game.headers["Black"])

first_game.mainline()  

first_game.headers["Result"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 3
#       1 import chess.pgn
# ----> 3 with open("data/pgn/molinari-bordais-1979.pgn") as pgn:
#       4     first_game = chess.pgn.read_game(pgn)
#       6 print(first_game.headers["White"])
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/pgn/molinari-bordais-1979.pgn'

# %%
import chess.syzygy

tablebase = chess.syzygy.open_tablebase("data/syzygy/regular")

# Black to move is losing in 53 half moves (distance to zero) in this
# KNBvK endgame.
board = chess.Board("8/2K5/4B3/3N4/8/8/4k3/8 b - - 0 1")
tablebase.probe_dtz(board)

tablebase.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 3
#       1 import chess.syzygy
# ----> 3 tablebase = chess.syzygy.open_tablebase("data/syzygy/regular")
#       5 # Black to move is losing in 53 half moves (distance to zero) in this
#       6 # KNBvK endgame.
#       7 board = chess.Board("8/2K5/4B3/3N4/8/8/4k3/8 b - - 0 1")
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/syzygy.py:1971, in open_tablebase(directory, load_wdl, load_dtz, max_fds, VariantBoard)
#    1952 """
#    1953 Opens a collection of tables for probing. See
#    1954 :class:`~chess.syzygy.Tablebase`.
#    (...)   1968     are closed, if necessary.
#    1969 """
#    1970 tables = Tablebase(max_fds=max_fds, VariantBoard=VariantBoard)
# -> 1971 tables.add_directory(directory, load_wdl=load_wdl, load_dtz=load_dtz)
#    1972 return tables
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/syzygy.py:1516, in Tablebase.add_directory(self, directory, load_wdl, load_dtz)
#    1503 """
#    1504 Adds tables from a directory.
#    1505
#    (...)   1513 Returns the number of table files that were found.
#    1514 """
#    1515 directory = os.path.abspath(directory)
# -> 1516 return sum(self.add_file(os.path.join(directory, filename), load_wdl=load_wdl, load_dtz=load_dtz) for filename in os.listdir(directory))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/minseo/Documents/Github/Chess_Tool_Pygame/data/syzygy/regular'

# %%
import chess.engine

engine = chess.engine.SimpleEngine.popen_uci("stockfish")

board = chess.Board("1k1r4/pp1b1R2/3q2pp/4p3/2B5/4Q3/PPP2B2/2K5 b - - 0 1")
limit = chess.engine.Limit(time=2.0)
engine.play(board, limit)  

engine.quit()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 3
#       1 import chess.engine
# ----> 3 engine = chess.engine.SimpleEngine.popen_uci("sf")
#       5 board = chess.Board("1k1r4/pp1b1R2/3q2pp/4p3/2B5/4Q3/PPP2B2/2K5 b - - 0 1")
#       6 limit = chess.engine.Limit(time=2.0)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/engine.py:3052, in SimpleEngine.popen_uci(cls, command, timeout, debug, setpgrp, **popen_args)
#    3046 @classmethod
#    3047 def popen_uci(cls, command: Union[str, List[str]], *, timeout: Optional[float] = 10.0, debug: Optional[bool] = None, setpgrp: bool = False, **popen_args: Any) -> SimpleEngine:
#    3048     """
#    3049     Spawns and initializes a UCI engine.
#    3050     Returns a :class:`~chess.engine.SimpleEngine` instance.
#    3051     """
# -> 3052     return cls.popen(UciProtocol, command, timeout=timeout, debug=debug, setpgrp=setpgrp, **popen_args)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/engine.py:3044, in SimpleEngine.popen(cls, Protocol, command, timeout, debug, setpgrp, **popen_args)
#    3041         simple_engine.close()
#    3042     await simple_engine.shutdown_event.wait()
# -> 3044 return run_in_background(background, name=f"{cls.__name__} (command={command!r})", debug=debug)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/engine.py:77, in run_in_background(coroutine, name, debug)
#      74         future.set_exception(exc)
#      76 threading.Thread(target=background, name=name).start()
# ---> 77 return future.result()
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/engine.py:71, in run_in_background.<locals>.background()
#      69 def background() -> None:
#      70     try:
# ---> 71         asyncio.run(coroutine(future), debug=debug)
#      72         future.cancel()
#      73     except Exception as exc:
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/asyncio/runners.py:190, in run(main, debug)
#     186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
# --> 190     return runner.run(main)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/asyncio/runners.py:118, in Runner.run(self, coro, context)
#     116 self._interrupt_count = 0
#     117 try:
# --> 118     return self._loop.run_until_complete(task)
#     119 except exceptions.CancelledError:
#     120     if self._interrupt_count > 0:
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/asyncio/base_events.py:654, in BaseEventLoop.run_until_complete(self, future)
#     651 if not future.done():
#     652     raise RuntimeError('Event loop stopped before Future completed.')
# --> 654 return future.result()
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/engine.py:3032, in SimpleEngine.popen.<locals>.background(future)
#    3031 async def background(future: concurrent.futures.Future[SimpleEngine]) -> None:
# -> 3032     transport, protocol = await Protocol.popen(command, setpgrp=setpgrp, **popen_args)
#    3033     threading.current_thread().name = f"{cls.__name__} (pid={transport.get_pid()})"
#    3034     simple_engine = cls(transport, protocol, timeout=timeout)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/site-packages/chess/engine.py:1212, in Protocol.popen(cls, command, setpgrp, **popen_args)
#    1208         else:
#    1209             # Before Python 3.11
#    1210             popen_args["start_new_session"] = True
# -> 1212 return await asyncio.get_running_loop().subprocess_exec(cls, *command, **popen_args)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/asyncio/base_events.py:1708, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1706     debug_log = f'execute program {program!r}'
#    1707     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1708 transport = await self._make_subprocess_transport(
#    1709     protocol, popen_args, False, stdin, stdout, stderr,
#    1710     bufsize, **kwargs)
#    1711 if self._debug and debug_log is not None:
#    1712     logger.info('%s: %r', debug_log, transport)
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/asyncio/unix_events.py:207, in _UnixSelectorEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     204     raise RuntimeError("asyncio.get_child_watcher() is not activated, "
#     205                        "subprocess support is not installed.")
#     206 waiter = self.create_future()
# --> 207 transp = _UnixSubprocessTransport(self, protocol, args, shell,
#     208                                   stdin, stdout, stderr, bufsize,
#     209                                   waiter=waiter, extra=extra,
#     210                                   **kwargs)
#     212 watcher.add_child_handler(transp.get_pid(),
#     213                           self._child_watcher_callback, transp)
#     214 try:
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/asyncio/base_subprocess.py:36, in BaseSubprocessTransport.__init__(self, loop, protocol, args, shell, stdin, stdout, stderr, bufsize, waiter, extra, **kwargs)
#      34 # Create the child process: set the _proc attribute
#      35 try:
# ---> 36     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#      37                 stderr=stderr, bufsize=bufsize, **kwargs)
#      38 except:
#      39     self.close()
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/asyncio/unix_events.py:818, in _UnixSubprocessTransport._start(self, args, shell, stdin, stdout, stderr, bufsize, **kwargs)
#     816     stdin, stdin_w = socket.socketpair()
#     817 try:
# --> 818     self._proc = subprocess.Popen(
#     819         args, shell=shell, stdin=stdin, stdout=stdout, stderr=stderr,
#     820         universal_newlines=False, bufsize=bufsize, **kwargs)
#     821     if stdin_w is not None:
#     822         stdin.close()
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/Documents/Github/Chess_Tool_Pygame/.conda/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sf'
